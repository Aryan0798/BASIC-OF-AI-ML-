# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
plt.style.use('fivethirtyeight')

# %%
df=pd.read_csv('train.csv')

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 349          350         0       3
# 859          860         0       3
# 230          231         1       1
# 187          188         1       1
# 42            43         0       3
# 493          494         0       1
# 855          856         1       3
# 707          708         1       1
# 129          130         0       3
# 655          656         0       2
#
#                                               Name     Sex   Age  SibSp  \
# 349                               Dimic, Mr. Jovan    male  42.0      0
# 859                               Razi, Mr. Raihed    male   NaN      0
# 230   Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
# 42                             Kraeff, Mr. Theodor    male   NaN      0
# 493                        Artagaveytia, Mr. Ramon    male  71.0      0
# 855                     Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 707              Calderhead, Mr. Edward Pennington    male  42.0      0
# 129                             Ekstrom, Mr. Johan    male  45.0      0
# 655                      Hickman, Mr. Leonard Mark    male  24.0      2
#
#      Parch        Ticket     Fare Cabin Embarked
# 349      0        315088   8.6625   NaN        S
# 859      0          2629   7.2292   NaN        C
# 230      0         36973  83.4750   C83        S
# 187      0        111428  26.5500   NaN        S
# 42       0        349253   7.8958   NaN        C
# 493      0      PC 17609  49.5042   NaN        C
# 855      1        392091   9.3500   NaN        S
# 707      0      PC 17476  26.2875   E24        S
# 129      0        347061   6.9750   NaN        S
# 655      0  S.O.C. 14879  73.5000   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8284\694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex  \
# 848          849         0       2          Harper, Rev. John    male
# 479          480         1       3   Hirvonen, Miss. Hildur E  female
# 105          106         0       3      Mionoff, Mr. Stoytcho    male
# 560          561         0       3   Morrow, Mr. Thomas Rowan    male
# 226          227         1       2  Mellors, Mr. William John    male
#
#            Age  SibSp  Parch     Ticket     Fare Embarked
# 848  28.000000      0      1     248727  33.0000        S
# 479   2.000000      0      1    3101298  12.2875        S
# 105  28.000000      0      0     349207   7.8958        S
# 560  29.699118      0      0     372622   7.7500        Q
# 226  19.000000      0      0  SW/PP 751  10.5000        S

# %%
df.iloc[128]
# Out:
# PassengerId                  129
# Survived                       1
# Pclass                         3
# Name           Peter, Miss. Anna
# Sex                       female
# Age                    29.699118
# SibSp                          1
# Parch                          1
# Ticket                      2668
# Fare                     22.3583
# Embarked                       C
# Name: 128, dtype: object

# %%
df['Embarked'].value_counts()
df['Embarked'].fillna('S',inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8284\53761723.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S',inplace=True)

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 764          765         0       3
# 353          354         0       3
# 801          802         1       2
# 42            43         0       3
# 319          320         1       1
# 654          655         0       3
# 208          209         1       3
# 62            63         0       1
# 878          879         0       3
#
#                                                   Name     Sex        Age  \
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.000000
# 764                             Eklund, Mr. Hans Linus    male  16.000000
# 353                          Arnold-Franchi, Mr. Josef    male  25.000000
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.000000
# 42                                 Kraeff, Mr. Theodor    male  29.699118
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.000000
# 654                       Hegarty, Miss. Hanora "Nora"  female  18.000000
# 208                          Carr, Miss. Helen "Ellen"  female  16.000000
# 62                         Harris, Mr. Henry Birkhardt    male  45.000000
# 878                                 Laleff, Mr. Kristo    male  29.699118
#
#      SibSp  Parch      Ticket      Fare Embarked
# 630      0      0       27042   30.0000        S
# 764      0      0      347074    7.7750        S
# 353      1      0      349237   17.8000        S
# 801      1      1  C.A. 31921   26.2500        S
# 42       0      0      349253    7.8958        C
# 319      1      1       16966  134.5000        C
# 654      0      0      365226    6.7500        Q
# 208      0      0      367231    7.7500        Q
# 62       1      0       36973   83.4750        S
# 878      0      0      349217    7.8958        S

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Survived']=df['Survived'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Sex']=df['Sex'].astype('category')
df['Age']=df['Age'].astype('int')
df['Embarked']=df['Embarked'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int64(4), object(2)
# memory usage: 52.8+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.countplot(df['Survived'])
death_percent=round((df['Survived'].value_counts().values[0]/891)*100)
print("Out of 891, {}% people died in the accident".format(death_percent))
plt.savefig('CountPlot.png')
# Out:
# Out of 891, 62% people died in the accident

# %%
print((df['Pclass'].value_counts()/891)*100)
sns.countplot(df['Pclass'])
plt.savefig('CountPlot1.png')
# Out:
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: count, dtype: float64

# %%
print((df['Sex'].value_counts()/891)*100)
sns.countplot(df['Sex'])
plt.savefig('CountPlot2.png')
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64

# %%
print((df['SibSp'].value_counts()))
sns.countplot(df['SibSp'])
plt.savefig('CountPlot3.png')
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
print((df['Parch'].value_counts()/891)*100)
sns.countplot(df['Parch'])
plt.savefig('CountPlot4.png')
# Out:
# Parch
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: count, dtype: float64

# %%
print((df['Embarked'].value_counts()/891)*100)
sns.countplot(df['Embarked'])
plt.savefig('CountPlot5.png')
# Out:
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64

# %%
sns.distplot(df['Age'])
print(df['Age'].skew())
print(df['Age'].kurt())
plt.savefig('DistPlot.png')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8284\655140141.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# 0.45956263424701577
# 0.9865867453652877

# %%
sns.boxplot(df['Age'])
plt.savefig('BoxPlot.png')

# %%
sns.distplot(df['Fare'])
plt.savefig('DistPlot1.png')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8284\2426488881.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])

# %%
print(df['Fare'].skew())
print(df['Fare'].kurt())
# Out:
# 4.787316519674893
# 33.39814088089868

# %%
sns.boxplot(df['Fare'])
plt.savefig('BoxPlot1.png')
