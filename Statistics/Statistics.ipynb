# %%
#Descriptive vs Inferential
#Population,Sample:-Random,Representative
#Static(Mean)
#Parameter

# %%
#Types of Data
#Numerical:-Continuous,Discrete
#Categorical:- Normal,Ordinal

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df['pclass'].value_counts().plot(kind='bar')
plt.savefig('Barchart.png')

# %%
df['pclass'].value_counts().plot(kind='pie',autopct='%0.2f')
plt.savefig('PieChart.png')

# %%
a=df['pclass'].value_counts()

# %%
b=((a/a.sum())*100).values

# %%
b
# Out:
# array([55.10662177, 24.24242424, 20.65095398])

# %%
c=[]
cf=0
for i in b:
    cf=cf+i
    c.append(cf)

# %%
c
# Out:
# [np.float64(55.106621773288445),
#  np.float64(79.34904601571269),
#  np.float64(100.0)]

# %%
plt.plot(c,marker='D')
plt.savefig('CummalativeFrequencyPlot')

# %%
d=df['age'].values

# %%
plt.hist(d)
plt.savefig('Histogram.png')

# %%
a=df.dropna(subset=['age'])
a=a['age'].values
np.median(a)
# Out:
# np.float64(28.0)

# %%
sns.boxplot(x='age',data=df)
plt.savefig('Boxplot.png')

# %%
sns.kdeplot(df['age'])
plt.savefig('KdePlot.png')

# %%
sns.boxplot(x='pclass',y='age',data=df)
plt.savefig('Multiboxplot.png')

# %%
sns.barplot(x='pclass',y='age',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
m=df['age'].values
n=df['fare'].values
plt.scatter(m,n)
plt.savefig('scatterplot.png')

# %%
pd.crosstab(df['pclass'],df['sex']).plot(kind='bar')
plt.savefig('crosstab.png')

# %%
ct=pd.crosstab(df['pclass'],df['sex'])

# %%
ct.plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
sns.heatmap(ct)
plt.savefig('Heatmap.png')

# %%
cf=sns.load_dataset('iris')

# %%
cf.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
cf.rename(columns={'sepal_length':'sl','sepal_width':'sw','petal_length':'pl','petal_width':'pw','species':'sp'},inplace=True)

# %%
cf['sp'].value_counts()
# Out:
# sp
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
