# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=d08bc87cb6dc6a0074b4c8fe8a4e7514&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id           title                                           overview  \
# 0  1368337     The Odyssey  Odysseus, the legendary King of Ithaca, embark...
# 1  1108427           Moana  Teenage Moana answers the Ocean's call and, fo...
# 2  1339713       Obsession  After breaking the mysterious "One Wish Willow...
# 3  1083381       Backrooms  A strange doorway appears in the basement of a...
# 4  1275779  Disclosure Day  A cybersecurity expert becomes a whistleblower...
#
#   release_date  popularity  vote_average  vote_count
# 0   2026-07-15    746.6132         7.820         713
# 1   2026-07-08    601.7817         5.788         117
# 2   2026-05-13    573.6836         8.250        3346
# 3   2026-05-27    453.2348         7.047        1772
# 4   2026-06-10    452.1308         6.700         905

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=d08bc87cb6dc6a0074b4c8fe8a4e7514&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df,temp_df],ignore_index=True)

# %%
df.shape
# Out:
# (10640, 7)

# %%
df.to_csv('movies.csv')
